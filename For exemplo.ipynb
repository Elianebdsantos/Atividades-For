# %%
for i in range(1,5):
  x= float(input("Digite um valor para x"))
  R= x*12
  print ("Resultado para a interação"), i, ":", R
# Out:
# Digite um valor para x2
# Resultado para a interação
# Digite um valor para x3
# Resultado para a interação
# Digite um valor para x4
# Resultado para a interação
# Digite um valor para x5
# Resultado para a interação
